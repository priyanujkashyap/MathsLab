# %%
#Question 1
from sympy import dsolve, Symbol, Function, tan, sin, pi, plot, diff, Eq 
x = Symbol('x')
y = Function('y')
de = Eq(diff(y(x),x)+ 2*tan(x)*y(x), sin(x))
y0 = {y(pi/3):0}
x1 = pi
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", sol.rhs)
print("The value of y at", x1, "is:", sol.rhs.subs(x,x1))
plot (sol.rhs, (x, pi/2, 2*pi), ylabel="y(x)")
# Out:
# The solution of the given DE is: (1 - 2*cos(x))*cos(x)
# The value of y at pi is: -3

# %%
#Question 2
from sympy import dsolve, Symbol, Function, plot, diff, Eq 
x = Symbol('x')
y = Function('y')
de = Eq(diff(y(x),x)+ (-1)*y(x), 0)
y0 = {y(0):1}
x1 = 2
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", sol.rhs)
print("The value of y at", x1, "is:", sol.rhs.subs(x,x1))
plot (sol.rhs, (x, 0, 2), ylabel="y(x)")
# Out:
# The solution of the given DE is: exp(x)
# The value of y at 2 is: exp(2)

# %%
#Question 3
from sympy import dsolve, Symbol, Function, tan, plot, diff, Eq, pi 
x = Symbol('x')
y = Function('y')
de = Eq(diff(y(x),x)+ 1/tan(x)*y(x), 1/tan(x))
y0 = {y(pi/2):1}
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", sol.rhs)
plot (sol.rhs, (x, 0, pi/2), ylabel="y(x)")
# Out:
# The solution of the given DE is: 1

# %%
#Question 4
from sympy import *
x = Symbol('x')
y = Function('y')
de = Eq(diff(y(x),x) + ((2*x)/(1+x**2))*y(x), 1/((1+x**2)**2))
y0 = {y(1):0}
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", sol.rhs)
plot (sol.rhs, (x, 0, pi/2), ylabel="y(x)")
# Out:
# The solution of the given DE is: (-I*log(x - I) + I*log(x + I) + pi/2)/(2*(x**2 + 1))

# %%
#Question 5
from sympy import dsolve, Symbol, Function, tan, plot, diff, Eq, pi 
x = Symbol('x')
y = Function('y')
de = Eq(diff(y(x),x)+ (1/x)*y(x), x**2)
y0 = {y(1):1}
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", sol.rhs)
plot (sol.rhs, (x, 0, pi/2), ylabel="y(x)")
# Out:
# The solution of the given DE is: (x**4/4 + 3/4)/x

# %%
#Question 1
from sympy import dsolve, Symbol, Function, plot, diff, Eq, pi, simplify
x = Symbol('x')
y = Function('y')
de = Eq(diff(y(x),x)+ (1/x)*y(x), y(x)**2)
y0 = {y(1):1}
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", simplify(sol.rhs))
plot (simplify(sol.rhs), (x, pi/2, 2*pi), ylabel="y(x)")
# Out:
# The solution of the given DE is: -1/(x*(log(x) - 1))

# %%
#Question 2
from sympy import dsolve, Symbol, Function, plot, diff, Eq, pi
x = Symbol('x')
y = Function('y')
de = Eq(x*diff(y(x),x) + y(x), x**2*y(x)**6)
y0 = {y(1):1}
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", sol.rhs)
plot (sol.rhs, (x, 0, 5), ylabel="y(x)")
# Out:
# The solution of the given DE is: 3**(1/5)*(1/(x**2*(5 - 2*x**3)))**(1/5)
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars

# %%
#Question 3
from sympy import dsolve, Symbol, Function, plot, diff, Eq, pi, tan
x = Symbol('x')
y = Function('y')
de = Eq(diff(y(x),x) - 2*y(x)*tan(x), y(x)**2*tan(x)**2)
y0 = {y(1):1}
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", simplify(sol.rhs))
plot (simplify(sol.rhs), (x, pi/2, 2*pi), ylabel="y(x)")
# Out:
# The solution of the given DE is: 3*cos(1)**3*cos(x)/(-sin(x)**3*cos(1)**3 + (sin(1)**3 + 3*cos(1))*cos(x)**3)

# %%
#Question 4
from sympy import dsolve, Symbol, Function, plot, diff, Eq, pi,log
x = Symbol('x')
y = Function('y')
de = Eq(x*diff(y(x),x)+ y(x), y(x)**2*log(x))
y0 = {y(1):1}
sol = dsolve(de,y(x),ics=y0)
print("The solution of the given DE is:", simplify(sol.rhs))
plot (simplify(sol.rhs), (x, pi/2, 2*pi), ylabel="y(x)")
# Out:
# The solution of the given DE is: 1/(log(x) + 1)
